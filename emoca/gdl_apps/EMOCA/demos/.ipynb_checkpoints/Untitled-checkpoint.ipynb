# %%
import pickle

# 指定要查看的pkl文件路径
file_path = '/home/ubuntu/code/emoca/gdl_apps/EMOCA/video_output/EMOCA_v2_lr_mse_20/processed_2024_Aug_16_12-13-24/metadata.pkl'

# 读取并加载pkl文件
with open(file_path, 'rb') as file:
    data = pickle.load(file)

# 查看数据内容
print(data)
# Out:
# 3

# %%
import sys
paths = sys.path
for path in paths:
    print(path)
# Out:
# /home/ubuntu/code/emoca/gdl_apps/EMOCA/demos
# /home/ubuntu/anaconda3/lib/python311.zip
# /home/ubuntu/anaconda3/lib/python3.11
# /home/ubuntu/anaconda3/lib/python3.11/lib-dynload
#
# /home/ubuntu/anaconda3/lib/python3.11/site-packages

# %%
from gdl_apps.EMOCA.utils.load import load_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from gdl_apps.EMOCA.utils.load import load_model
#
# ModuleNotFoundError: No module named 'gdl_apps'

# %%
sys.path.append('/home/ubuntu/code/emoca')
